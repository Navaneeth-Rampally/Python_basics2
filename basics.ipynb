# %% [markdown]
# #Lists

# %%
l1 = ['Nava', 'Rampally', 1, 2, 22.78, True]
l2 = ['Rampally', 'Nava', 3, 4, 78.22, False]
l3 = l1+l2
l3
# Out:
# ['Nava', 'Rampally', 1, 2, 22.78, True, 'Rampally', 'Nava', 3, 4, 78.22, False]
